# %%
import pandas as pd
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# show installed versions
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pd.__version__
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: &#39;0.24.2&#39;</div>

# %%
np.__version__
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: &#39;1.16.2&#39;</div>

# %%
#show dependencies versions
pd.show_versions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.7.3.final.0
# python-bits: 64
# OS: Linux
# OS-release: 4.15.0-1050-azure
# machine: x86_64
# processor: x86_64
# byteorder: little
# LC_ALL: None
# LANG: en_US.UTF-8
# LOCALE: en_US.UTF-8
#
# pandas: 0.24.2
# pytest: None
# pip: 19.0.3
# setuptools: 40.8.0
# Cython: 0.29.6
# numpy: 1.16.2
# scipy: 1.4.1
# pyarrow: 0.13.0
# xarray: None
# IPython: 7.4.0
# sphinx: None
# patsy: 0.5.1
# dateutil: 2.8.0
# pytz: 2018.9
# blosc: None
# bottleneck: None
# tables: None
# numexpr: None
# feather: None
# matplotlib: 3.0.3
# openpyxl: 3.0.3
# xlrd: 1.2.0
# xlwt: None
# ...

# %%
#create dataframes as examples
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create a df passing a dictionary to the dataframe constructor, in which the dictionary keys, are the column names and the dictionary values are lists of column values
df = pd.DataFrame({"col1":[100, 200], "col2":[300,400]})
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>100</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>200</td>
#       <td>400</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# for a much larger df, we can use numpy, using the random.rand function, to tell the number of rows and columns
pd.DataFrame(np.random.rand(4,8))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.250526</td>
#       <td>0.169816</td>
#       <td>0.043467</td>
#       <td>0.428222</td>
#       <td>0.983969</td>
#       <td>0.491855</td>
#       <td>0.074110</td>
#       <td>0.852503</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.635657</td>
#       <td>0.355120</td>
#       <td>0.982295</td>
#       <td>0.492443</td>
#       <td>0.235586</td>
#       <td>0.012372</td>
# ...

# %%
# for non-numeric columns, we can use a list of strings
pd.DataFrame(np.random.rand(4,8), columns=list("abcdefgh"))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>e</th>
#       <th>f</th>
#       <th>g</th>
#       <th>h</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.641134</td>
#       <td>0.863199</td>
#       <td>0.355899</td>
#       <td>0.944895</td>
#       <td>0.251701</td>
#       <td>0.104487</td>
#       <td>0.583419</td>
#       <td>0.174463</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.909690</td>
#       <td>0.802861</td>
#       <td>0.974965</td>
#       <td>0.460798</td>
#       <td>0.431280</td>
#       <td>0.714346</td>
# ...

# %%
# rename columns
df = pd.DataFrame({"col1":[100, 200], "col2":[300,400]})
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>100</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>200</td>
#       <td>400</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = df.rename({"col1":"col one", "col2":"col two"}, axis="columns")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col one</th>
#       <th>col two</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>100</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>200</td>
#       <td>400</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#another way of renaming columns is with a list
df = df.rename({"col1":"col one", "col2":"col two"}, axis="columns")
df.columns=["col_one", "col_two"]
df.columns = df.columns.str.replace(" ", "_")
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col_one</th>
#       <th>col_two</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>100</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>200</td>
#       <td>400</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#reverse row order
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
storage_account_name = "hugoestradassa"
storage_account_access_key = "TnecMMpdWfQN5IUoV6wfjQEs1mYi+EfeG3GhOoV8ZBndA044bbNTluBpI4sQwqkk5zuot8NShAVboXoQXNDl8g=="
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
file_location = "wasbs://dataanalysis@hugoestradassa.blob.core.windows.net/drinks.csv"
file_type = "csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set(
  "fs.azure.account.key."+storage_account_name+".blob.core.windows.net",
  storage_account_access_key)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.format(file_type).option("inferSchema", "true").load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
pdf = df
pandas_dataframe = df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_dataframe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>_c1</th>
#       <th>_c2</th>
#       <th>_c3</th>
#       <th>_c4</th>
#       <th>_c5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>country</td>
#       <td>beer_servings</td>
#       <td>spirit_servings</td>
#       <td>wine_servings</td>
#       <td>total_litres_of_pure_alcohol</td>
#       <td>continent</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Afghanistan</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albania</td>
# ...

# %%
pandas_dataframe.drop(pandas_dataframe.index[:1], inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_dataframe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>_c1</th>
#       <th>_c2</th>
#       <th>_c3</th>
#       <th>_c4</th>
#       <th>_c5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Afghanistan</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albania</td>
#       <td>89</td>
#       <td>132</td>
#       <td>54</td>
#       <td>4.9</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Algeria</td>
#       <td>25</td>
#       <td>0</td>
#       <td>14</td>
# ...

# %%
pandas_dataframe = pandas_dataframe.rename({"_c0":"country", "_c1":"beer_servings", "_c2":"spirit_servings", "_c3":"wine_servings", "_c4":"total_litres_of_pure_alcohol", "_c5":"continent"}, axis="columns")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_dataframe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>beer_servings</th>
#       <th>spirit_servings</th>
#       <th>wine_servings</th>
#       <th>total_litres_of_pure_alcohol</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Afghanistan</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albania</td>
#       <td>89</td>
#       <td>132</td>
#       <td>54</td>
#       <td>4.9</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Algeria</td>
# ...

# %%
pandas_dataframe.columns = pandas_dataframe.columns.str.replace("_", " ")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_dataframe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>beer servings</th>
#       <th>spirit servings</th>
#       <th>wine servings</th>
#       <th>total litres of pure alcohol</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Afghanistan</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albania</td>
#       <td>89</td>
#       <td>132</td>
#       <td>54</td>
#       <td>4.9</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Algeria</td>
# ...

# %%
# reverse reow order
pandas_dataframe.loc[::-1].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>beer servings</th>
#       <th>spirit servings</th>
#       <th>wine servings</th>
#       <th>total litres of pure alcohol</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>193</th>
#       <td>Zimbabwe</td>
#       <td>64</td>
#       <td>18</td>
#       <td>4</td>
#       <td>4.7</td>
#       <td>Africa</td>
#     </tr>
#     <tr>
#       <th>192</th>
#       <td>Zambia</td>
#       <td>32</td>
#       <td>19</td>
#       <td>4</td>
#       <td>2.5</td>
#       <td>Africa</td>
#     </tr>
#     <tr>
#       <th>191</th>
#       <td>Yemen</td>
# ...

# %%
pandas_dataframe.loc[::-1].reset_index(drop=True).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>beer servings</th>
#       <th>spirit servings</th>
#       <th>wine servings</th>
#       <th>total litres of pure alcohol</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Zimbabwe</td>
#       <td>64</td>
#       <td>18</td>
#       <td>4</td>
#       <td>4.7</td>
#       <td>Africa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Zambia</td>
#       <td>32</td>
#       <td>19</td>
#       <td>4</td>
#       <td>2.5</td>
#       <td>Africa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Yemen</td>
# ...

# %%
# reverse column order
pandas_dataframe.loc[:, ::-1].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>continent</th>
#       <th>total litres of pure alcohol</th>
#       <th>wine servings</th>
#       <th>spirit servings</th>
#       <th>beer servings</th>
#       <th>country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Asia</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Europe</td>
#       <td>4.9</td>
#       <td>54</td>
#       <td>132</td>
#       <td>89</td>
#       <td>Albania</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Africa</td>
# ...

# %%
# select columns by data type
pandas_dataframe.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[69]: country                         object
# beer servings                   object
# spirit servings                 object
# wine servings                   object
# total litres of pure alcohol    object
# continent                       object
# dtype: object</div>
