# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Fire_Department_Calls_for_Service_10.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 44 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Call Number                                           2000 non-null   int64
#  1   Unit ID                                               2000 non-null   object
#  2   Incident Number                                       2000 non-null   int64
#  3   Call Type                                             2000 non-null   object
#  4   Call Date                                             2000 non-null   object
#  5   Watch Date                                            2000 non-null   object
#  6   Received DtTm                                         2000 non-null   object
#  7   Entry DtTm                                            2000 non-null   object
# ...

# %%
df.head()
# Out:
#    Call Number Unit ID  Incident Number         Call Type   Call Date  \
# 0    193341572     T02         19144174            Alarms  11/30/2019
# 1    193101900     RC3         19134022  Medical Incident   11/6/2019
# 2    200071312     E01         20002815            Alarms    1/7/2020
# 3    193601143     RC1         19155796  Medical Incident  12/26/2019
# 4    200310051      54         20013094  Medical Incident   1/31/2020
#
#    Watch Date     Received DtTm        Entry DtTm     Dispatch DtTm  \
# 0  11/30/2019  11/30/2019 13:55  11/30/2019 13:56  11/30/2019 13:56
# 1   11/6/2019   11/6/2019 12:11   11/6/2019 12:12   11/6/2019 12:12
# 2    1/7/2020    1/7/2020 10:25    1/7/2020 10:26    1/7/2020 10:26
# 3  12/26/2019  12/26/2019 11:06  12/26/2019 11:06  12/26/2019 11:07
# 4   1/30/2020    1/31/2020 0:23    1/31/2020 0:24    1/31/2020 0:24
#
#       Response DtTm  ... Supervisor Districts Fire Prevention Districts  \
# ...

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df.head()
# Out:
#    Call_Number Unit_ID  Incident_Number         Call_Type   Call_Date  \
# 0    193341572     T02         19144174            Alarms  11/30/2019
# 1    193101900     RC3         19134022  Medical Incident   11/6/2019
# 2    200071312     E01         20002815            Alarms    1/7/2020
# 3    193601143     RC1         19155796  Medical Incident  12/26/2019
# 4    200310051      54         20013094  Medical Incident   1/31/2020
#
#    Watch_Date     Received_DtTm        Entry_DtTm     Dispatch_DtTm  \
# 0  11/30/2019  11/30/2019 13:55  11/30/2019 13:56  11/30/2019 13:56
# 1   11/6/2019   11/6/2019 12:11   11/6/2019 12:12   11/6/2019 12:12
# 2    1/7/2020    1/7/2020 10:25    1/7/2020 10:26    1/7/2020 10:26
# 3  12/26/2019  12/26/2019 11:06  12/26/2019 11:06  12/26/2019 11:07
# 4   1/30/2020    1/31/2020 0:23    1/31/2020 0:24    1/31/2020 0:24
#
#       Response_DtTm  ... Supervisor_Districts Fire_Prevention_Districts  \
# ...

# %%
classes, counts = np.unique(df["Call_Type"], return_counts=True)

# %%
print (classes) 
print ("\n")
print (counts)
# Out:
# ['Alarms' 'Citizen Assist / Service Call' 'Electrical Hazard'
#  'Elevator / Escalator Rescue' 'Explosion'
#  'Gas Leak (Natural and LP Gases)' 'HazMat' 'High Angle Rescue'
#  'Medical Incident' 'Odor (Strange / Unknown)' 'Other' 'Outside Fire'
#  'Smoke Investigation (Outside)' 'Structure Fire' 'Traffic Collision'
#  'Vehicle Fire' 'Water Rescue']
#
#
# [ 201   32   11    8    1   16    3    1 1418    3   27   28    7  158
#    74    5    7]

# %%
df = pd.DataFrame({"Call_Type":[classes], "Quantity":[counts]})

# %%
df.head()
# Out:
#                                            Call_Type  \
# 0  [Alarms, Citizen Assist / Service Call, Electr...
#
#                                             Quantity
# 0  [201, 32, 11, 8, 1, 16, 3, 1, 1418, 3, 27, 28,...

# %%
df = pd.DataFrame({"Call_Type":classes, "Quantity":counts})

# %%
df.head()
# Out:
#                        Call_Type  Quantity
# 0                         Alarms       201
# 1  Citizen Assist / Service Call        32
# 2              Electrical Hazard        11
# 3    Elevator / Escalator Rescue         8
# 4                      Explosion         1

# %%
df
# Out:
#                           Call_Type  Quantity
# 0                            Alarms       201
# 1     Citizen Assist / Service Call        32
# 2                 Electrical Hazard        11
# 3       Elevator / Escalator Rescue         8
# 4                         Explosion         1
# 5   Gas Leak (Natural and LP Gases)        16
# 6                            HazMat         3
# 7                 High Angle Rescue         1
# 8                  Medical Incident      1418
# 9          Odor (Strange / Unknown)         3
# 10                            Other        27
# 11                     Outside Fire        28
# 12    Smoke Investigation (Outside)         7
# 13                   Structure Fire       158
# 14                Traffic Collision        74
# 15                     Vehicle Fire         5
# 16                     Water Rescue         7

# %%
df.plot(kind='scatter',x='Call_Type',y='Quantity',color='red')
plt.show()

# %%
df.plot(kind='bar',x='Call_Type',y='Quantity')

# %%
from sqlalchemy import create_engine

# %%
# !pip install psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 10.4 MB/s eta 0:00:01
# ...

# %%
con = create_engine("postgres://postgres:secret@postgres")

# %%
df.to_sql(
    name="firecalls",
    con=con,
    if_exists="append",
    index=False
)
